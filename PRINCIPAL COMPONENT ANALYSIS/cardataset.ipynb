# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Load and preprocess the data
file_path = 'car_data.csv'
car_data = pd.read_csv(file_path)

car_data['Age'].fillna(car_data['Age'].mean(), inplace=True)
car_data['AnnualSalary'].fillna(car_data['AnnualSalary'].mean(), inplace=True)

label_encoder = LabelEncoder()
car_data['Gender'] = label_encoder.fit_transform(car_data['Gender'])

x = car_data[['Age', 'AnnualSalary']]

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# Apply PCA
pca_model = PCA(n_components=2)
x_pca = pca_model.fit_transform(x_scaled)

# Plotting PCA results
plt.figure(figsize=(10, 10))
plt.scatter(x_pca[:, 0], x_pca[:, 1], c='black')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Car Dataset')
plt.show()

# Display selected records
records_to_display = [132, 183, 316, 399, 986]
print("Records:")
print(car_data.iloc[records_to_display])

# Print explained variance
explained_variance = pca_model.explained_variance_ratio_
print(f"Explained variance by each component: {explained_variance}")
# Out:
# Records:
#      User ID  Gender       Age  AnnualSalary  Purchased
# 132      133       0  40.14343  65500.000000          0
# 183      184       0  40.14343  83500.000000          0
# 316      317       0  38.00000  72737.975952          0
# 399      400       1  30.00000  72737.975952          0
# 986      987       1  40.14343  20500.000000          0
# Explained variance by each component: [0.58140695 0.41859305]
